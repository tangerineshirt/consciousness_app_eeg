# %%
import h5py
import pandas as pd
import numpy as np

mat_path = "/home/razzannr/Documents/GitHub/consciousness_app_eeg/eeg_data/case1.mat"

with h5py.File(mat_path, "r") as f:
    print("Daftar variabel:")
    for key in f.keys():
        print(key)

    var_name = "EEG"
    data = np.array(f[var_name]).squeeze()

df = pd.DataFrame({"AF7": data})
df.to_csv("hasil_af7.csv", index=False)

print("Berhasil disimpan ke hasil_af7.csv")
# Out:
# Daftar variabel:
# EEG
# bis
# Berhasil disimpan ke hasil_af7.csv
